# %%
import re
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import platform
import warnings

warnings.filterwarnings('ignore')

from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Okt
from collections import Counter
from PIL import Image
from wordcloud import WordCloud

# %%
path = 'c:/Windows/Fonts/malgun.ttf'
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname = path).get_name()
    rc('font', family = font_name)
else:
    print('Unknown system. Sorry.')

get_ipython().run_line_magic('matplotlib', 'inline')

# %% [markdown]
# # 1. Import data

# %%
df = pd.read_csv('./data/naver_shopping.txt', sep = '\t', encoding = 'utf-8', header = None)
df.columns = ['rating','text']
df.head()
# Out:
#    rating                                               text
# 0       5                                            배공빠르고 굿
# 1       2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2       5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3       2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4       5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ

# %% [markdown]
# # 2. 데이터 살펴보기

# %%
# dimension
df.shape
# Out:
# (200000, 2)

# %%
# 결측치
df.isnull().sum()
# Out:
# rating    0
# text      0
# dtype: int64

# %%
# information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   rating  200000 non-null  int64
#  1   text    200000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 3.1+ MB

# %%
# reviews 변수 확인
df['text'][0]
# Out:
# '배공빠르고 굿'

# %% [markdown]
# ### 평점별 리뷰 개수

# %%
sns.countplot(y = 'rating', data = df);

# %%
df['rating'].value_counts()
# Out:
# 5    81177
# 2    63989
# 1    36048
# 4    18786
# Name: rating, dtype: int64

# %% [markdown]
# | |1점|2점|4점|5점|
# |---|---|---|---|---|
# |개수|36,048|63,989|18,786|81,177|

# %% [markdown]
# ### 긍/부정 label 추가 및 확인

# %%
df['p/n'] = np.where(df['rating'].values > 3, 1, 0)
df.head()
# Out:
#    rating                                               text  p/n
# 0       5                                            배공빠르고 굿    1
# 1       2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고    0
# 2       5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...    1
# 3       2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...    0
# 4       5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ    1

# %%
sns.countplot(y = 'p/n', data = df);

# %%
df['p/n'].value_counts()
# Out:
# 0    100037
# 1     99963
# Name: p/n, dtype: int64

# %% [markdown]
# | |긍정리뷰|부정리뷰|
# |---|---|---|
# |개수|100,037|99,963|
# |비율 (%)|50.012|49.98|

# %% [markdown]
# # 3. File Decomposition

# %%
Score_1_Review = []

for idx, row in df.iterrows():
    if df.iloc[idx, 0] == 1 :
        Score_1_Review.append(df.iloc[idx,1])

filePath = './Score_1_Review.txt'
with open(filePath, 'w+', encoding = 'utf-8') as lf:
    lf.write(' '.join(Score_1_Review))

# %%
Score_2_Review = []

for idx, row in df.iterrows():
    if df.iloc[idx, 0] == 2 :
        Score_2_Review.append(df.iloc[idx,1])

filePath = './Score_2_Review.txt'
with open(filePath, 'w+', encoding = 'utf-8') as lf:
    lf.write(' '.join(Score_2_Review))

# %%
Score_4_Review = []

for idx, row in df.iterrows():
    if df.iloc[idx, 0] == 4 :
        Score_4_Review.append(df.iloc[idx,1])

filePath = './Score_4_Review.txt'
with open(filePath, 'w+', encoding = 'utf-8') as lf:
    lf.write(' '.join(Score_4_Review))

# %%
Score_5_Review = []

for idx, row in df.iterrows():
    if df.iloc[idx, 0] == 5 :
        Score_5_Review.append(df.iloc[idx,1])

filePath = './Score_5_Review.txt'
with open(filePath, 'w+', encoding = 'utf-8') as lf:
    lf.write(' '.join(Score_5_Review))

# %% [markdown]
# # 4. Word Cloud

# %% [markdown]
# ## (1) Score_1_Review

# %%
text = ''
filePath = './data/Score_1_Review.txt'
with open(filePath, "r", encoding="utf-8") as f:
    lines = f.readlines()
    for line in lines:
        text += line

# %%
#### 불용어
stopwords = pd.read_csv('./data/korean_stopwords.txt').values.tolist()
stopwords[:10]
# Out:
# [['휴'],
#  ['아이구'],
#  ['아이쿠'],
#  ['아이고'],
#  ['어'],
#  ['나'],
#  ['우리'],
#  ['저희'],
#  ['따라'],
#  ['의해']]

# %%
# 전처리 - 명사 추출
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]')  # 정규 표현식 처리
    result = hangul.sub('', text)
    
    tagger = Okt()
    nouns = tagger.nouns(result)
    nouns = [x for x in nouns if len(x) > 1]           # 한 글자 키워드 제거 (ex) 것, 개, 거, 때, ...
    nouns = [x for x in nouns if x not in stopwords]  # 불용어 제거
    
    return nouns

# %%
vect = CountVectorizer(tokenizer = lambda x : text_cleaning(x))
bow_vect = vect.fit_transform([text])
word_list = vect.get_feature_names_out()
count_list = bow_vect.toarray().sum(axis = 0)

# %%
mask = np.array(Image.open('./cloud.png'))

plt.imshow(mask, cmap = plt.cm.gray, interpolation = 'bilinear')
plt.axis('off')
plt.show();

# %%
word_count_dict = dict(zip(word_list, count_list))
word_count_dict
# Out:
# {'가가': 8,
#  '가게': 29,
#  '가격': 1476,
#  '가격표': 4,
#  '가계': 2,
#  '가공': 14,
#  '가공품': 1,
#  '가관': 7,
#  '가구': 58,
#  '가구라': 1,
#  '가구점': 2,
#  '가글': 1,
#  '가기': 7,
#  '가까이': 44,
#  '가끔': 31,
#  '가나': 49,
#  '가나다': 11,
#  '가나다라': 1,
#  '가년': 2,
#  '가늠': 3,
#  '가늡니': 1,
#  '가능': 16,
#  '가능성': 2,
#  '가다가': 2,
#  '가다랑어': 1,
#  '가닥': 13,
#  '가당': 3,
#  '가대': 1,
#  '가도': 13,
#  '가독성': 1,
#  '가동': 5,
#  '가드': 17,
#  '가득': 33,
#  '가든': 1,
#  '가디': 1,
#  '가디건': 2,
#  '가뜩이나': 1,
#  '가라': 7,
#  '가라아게': 1,
#  '가락': 7,
#  '가랑이': 14,
#  '가래': 2,
#  '가래떡': 2,
#  '가랭': 1,
#  '가량': 20,
#  '가럭저럭': 1,
#  '가렌드': 1,
#  '가려움': 11,
#  '가려움증': 3,
#  '가력': 1,
#  '가렵': 12,
#  '가렵기': 1,
#  '가렵네': 3,
#  '가렵니': 1,
#  '가렵다': 2,
#  '가렵습니': 1,
#  '가례': 1,
#  '가로': 20,
#  '가로등': 1,
#  '가로세로': 7,
#  '가루': 162,
#  '가루타': 1,
#  '가르침': 1,
#  '가름': 1,
#  '가리개': 3,
#  '가리비': 18,
#  '가림': 3,
#  '가마': 1,
#  '가망': 1,
#  '가면': 21,
#  '가모': 3,
#  '가목': 1,
#  '가묘': 1,
#  '가문': 3,
#  '가물': 4,
#  '가미': 2,
#  '가바': 9,
#  '가발': 1,
#  '가방': 148,
#  '가변': 1,
#  '가보': 2,
#  '가볼껄': 1,
#  '가분': 1,
#  '가불': 1,
#  '가빠하': 1,
#  '가사': 5,
#  '가산': 1,
#  '가설': 1,
#  '가성': 121,
#  '가세': 8,
#  '가셧': 1,
#  '가셧는데': 1,
#  '가소': 1,
#  '가속': 1,
#  '가솔린': 1,
#  '가스': 13,
#  '가스렌지': 5,
#  '가스켓': 1,
#  '가스통': 1,
#  '가슴': 109,
#  '가슴골': 1,
#  '가슴통': 2,
#  '가습기': 16,
#  '가시': 40,
#  '가시도': 2,
#  '가신': 1,
#  '가썪었어': 1,
#  '가안': 32,
#  '가야': 15,
#  '가약': 1,
#  '가열': 8,
#  '가오': 4,
#  '가왜': 3,
#  '가요': 253,
#  '가용': 3,
#  '가운': 7,
#  '가운데': 66,
#  '가원': 4,
#  '가위': 40,
#  '가유': 1,
#  '가을': 14,
#  '가이드': 17,
#  '가이드라인': 1,
#  '가일': 1,
#  '가입': 7,
#  '가자미': 3,
#  '가작': 4,
#  '가장': 46,
#  '가장자리': 14,
#  '가재': 4,
#  '가전': 2,
#  '가전제품': 1,
#  '가정': 16,
#  '가정은': 1,
#  '가제': 1,
#  '가조': 1,
#  '가족': 36,
#  '가주': 5,
#  '가죽': 60,
#  '가중': 1,
#  '가지': 172,
#  '가지각색': 1,
#  '가짐': 2,
#  '가짓수': 1,
#  '가짜': 21,
#  '가차': 3,
#  '가책': 1,
#  '가체': 3,
#  '가취': 1,
#  '가치': 24,
#  '가타': 5,
#  '가터': 1,
#  '가평': 1,
#  '가포': 1,
#  '가품': 24,
#  '가해': 5,
#  '가해진': 1,
#  '가형': 5,
#  '각각': 23,
#  '각개': 4,
#  '각기': 1,
#  '각도': 20,
#  '각렌치': 2,
#  '각목': 1,
#  '각별': 1,
#  '각봉': 1,
#  '각성': 1,
#  '각심': 1,
#  '각오': 8,
#  '각인': 13,
#  '각자': 4,
#  '각재': 4,
#  '각질': 39,
#  '각하': 2,
#  '간걸': 2,
#  '간격': 13,
#  '간과': 1,
#  '간다': 12,
#  '간단': 1,
#  '간도': 7,
#  '간만': 3,
#  '간봉': 1,
#  '간섭': 5,
#  '간수': 1,
#  '간수치': 2,
#  '간식': 22,
#  '간위': 1,
#  '간이': 11,
#  '간장': 37,
#  '간장게장': 16,
#  '간전': 2,
#  '간절': 1,
#  '간접': 1,
#  '간정': 5,
#  '간주': 1,
#  '간지': 3,
#  '간직': 2,
#  '간쯔': 1,
#  '간편': 2,
#  '간혹': 4,
#  '간혼': 1,
#  '갇네': 1,
#  '갈고': 3,
#  '갈고리': 1,
#  '갈기': 2,
#  '갈대': 1,
#  '갈도': 1,
#  '갈등': 1,
#  '갈라': 4,
#  '갈라쟈': 1,
#  '갈래': 1,
#  '갈리': 10,
#  '갈릴': 2,
#  '갈비': 14,
#  '갈비뼈': 2,
#  '갈비살': 7,
#  '갈색': 20,
#  '갈수': 3,
#  '갈수록': 14,
#  '갈이': 4,
#  '갈증': 1,
#  '갈치': 7,
#  '감각': 1,
#  '감겨': 2,
#  '감고': 11,
#  '감귤': 2,
#  '감기': 12,
#  '감당': 10,
#  '감동': 3,
#  '감땜': 1,
#  '감량': 3,
#  '감마': 1,
#  '감뭐': 1,
#  '감별': 1,
#  '감사': 15,
#  '감사용': 1,
#  '감상': 1,
#  '감샤': 1,
#  '감성': 2,
#  '감소': 1,
#  '감수': 10,
#  '감시': 1,
#  '감안': 46,
#  '감염': 1,
#  '감옥': 1,
#  '감옶': 1,
#  '감자': 57,
#  '감자탕': 1,
#  '감전': 1,
#  '감점': 1,
#  '감정': 1,
#  '감지': 2,
#  '감지기': 2,
#  '감쪽': 1,
#  '감초': 2,
#  '감촉': 2,
#  '감칠맛': 3,
#  '감탄': 1,
#  '감히': 1,
#  '갑각류': 1,
#  '갑농': 1,
#  '갑바': 2,
#  '갑부': 2,
#  '갑빠': 1,
#  '갑오': 1,
#  '갑오징어': 6,
#  '갑옷': 1,
#  '갑자기': 70,
#  '값땜': 1,
#  '값어치': 14,
#  '갓김치': 7,
#  '강가': 1,
#  '강경': 1,
#  '강구': 1,
#  '강꿀맛': 1,
#  '강낭콩': 1,
#  '강냉이': 1,
#  '강도': 21,
#  '강동': 2,
#  '강된장': 2,
#  '강두': 1,
#  '강력': 16,
#  '강매': 5,
#  '강사': 2,
#  '강서구': 1,
#  '강아지': 59,
#  '강약': 1,
#  '강의': 1,
#  '강정': 2,
#  '강제': 5,
#  '강조': 5,
#  '강쥐': 3,
#  '강철': 3,
#  '강추': 5,
#  '강판': 1,
#  '강품': 1,
#  '강풍': 1,
#  '강하': 2,
#  '강화': 11,
#  '강화유리': 44,
#  '강화필르': 1,
#  '갖다버렷': 1,
#  '갖은': 2,
#  '같슴니': 1,
#  '같윤제품': 1,
#  '같은덴': 1,
#  '같이왓던': 1,
#  '개간': 1,
#  '개개': 1,
#  '개개인': 1,
#  '개겹쳐왓': 1,
#  '개경': 1,
#  '개구': 9,
#  '개구리': 1,
#  '개국': 2,
#  '개궁새': 1,
#  '개그': 1,
#  '개극혐': 1,
#  '개기찮': 1,
#  '개껌': 2,
#  '개꼴': 1,
#  '개꼽': 1,
#  '개나리': 1,
#  '개념': 5,
#  '개님': 1,
#  '개대': 1,
#  '개덜옴': 1,
#  '개도': 73,
#  '개두': 1,
#  '개떡': 4,
#  '개똥': 4,
#  '개똥망': 1,
#  '개똥이': 1,
#  '개량': 2,
#  '개롤': 1,
#  '개맛': 4,
#  '개망': 2,
#  '개무셩': 1,
#  '개무시': 2,
#  '개미': 13,
#  '개반': 2,
#  '개발': 4,
#  '개밥': 2,
#  '개별': 52,
#  '개보': 6,
#  '개복치': 1,
#  '개봉': 127,
#  '개봉시': 2,
#  '개봉씰': 1,
#  '개불': 5,
#  '개붙혔는데': 1,
#  '개비': 7,
#  '개빡쎔': 1,
#  '개뿔': 23,
#  '개사': 19,
#  '개산': 1,
#  '개살바': 1,
#  '개삿': 3,
#  '개삿는데': 5,
#  '개선': 60,
#  '개설': 2,
#  '개소': 1,
#  '개수': 13,
#  '개시': 48,
#  '개심': 1,
#  '개썩엇네': 1,
#  '개안조쿠': 1,
#  '개암': 1,
#  '개업': 2,
#  '개옴': 2,
#  '개왓': 1,
#  '개왓네': 1,
#  '개왓음': 1,
#  '개요': 1,
#  '개월': 87,
#  '개월안': 1,
#  '개월여': 1,
#  '개월용': 1,
#  '개월전': 2,
#  '개월차때': 1,
#  '개인': 91,
#  '개인화': 1,
#  '개임': 2,
#  '개입': 7,
#  '개잡침': 1,
#  '개장': 1,
#  '개전': 1,
#  '개정': 17,
#  '개젖': 1,
#  '개젛움': 1,
#  '개조': 3,
#  '개중': 101,
#  '개지': 2,
#  '개진': 1,
#  '개짐': 3,
#  '개짲응': 1,
#  '개체': 3,
#  '개취': 3,
#  '개콘': 1,
#  '개털': 4,
#  '개통': 1,
#  '개파심': 1,
#  '개판': 69,
#  '개폐': 1,
#  '개포': 1,
#  '개피': 1,
#  '개학': 2,
#  '개황': 1,
#  '개후짐': 1,
#  '개후짐털': 1,
#  '객지': 1,
#  '갠눴': 1,
#  '갠데': 1,
#  '갠찮': 1,
#  '갠찮더라구': 1,
#  '갠찮은데': 1,
#  '갠취': 1,
#  '갤노트을': 1,
#  '갤러리': 1,
#  '갤럭시': 19,
#  '갤럭시탭': 1,
#  '갤탭': 3,
#  '갮함': 1,
#  '갯가재': 2,
#  '갯수': 32,
#  '갯스': 1,
#  '갯핑': 1,
#  '갱년기': 1,
#  '갱쥐': 1,
#  '갲너': 1,
#  '거가': 15,
#  '거교': 1,
#  '거구': 1,
#  '거금': 2,
#  '거기': 64,
#  '거꾸로': 5,
#  '거나': 32,
#  '거눌': 1,
#  '거늘': 1,
#  '거니': 1,
#  '거도': 6,
#  '거두': 2,
#  '거땜': 1,
#  '거랕금키더': 1,
#  '거래': 23,
#  '거래처': 4,
#  '거러': 3,
#  '거려': 47,
#  '거렸': 1,
#  '거렸습니': 1,
#  '거르': 4,
#  '거르는': 1,
#  '거르세': 1,
#  '거를렵니': 1,
#  '거름': 8,
#  '거리': 178,
#  '거린': 1,
#  '거릴': 1,
#  '거릴때': 1,
#  '거림': 10,
#  '거립니': 7,
#  '거마': 9,
#  '거만': 17,
#  '거머': 1,
#  '거머리': 1,
#  '거멓': 1,
#  '거무': 1,
#  '거뭇거뭇': 5,
#  '거뭐': 4,
#  '거미줄': 1,
#  '거반': 2,
#  '거벨': 1,
#  '거보': 1,
#  '거부': 16,
#  '거북': 1,
#  '거북목': 3,
#  '거북이': 2,
#  '거사': 32,
#  '거산': 2,
#  '거살걸': 1,
#  '거살돈': 1,
#  '거살바': 1,
#  '거속': 1,
#  '거슥': 1,
#  '거슨': 1,
#  '거식증': 1,
#  '거실': 30,
#  '거여': 2,
#  '거오': 1,
#  '거옴': 1,
#  '거왜': 1,
#  '거왜안': 1,
#  '거울': 83,
#  '거원': 4,
#  '거의': 305,
#  '거인': 2,
#  '거임': 5,
#  '거장': 1,
#  '거잭': 6,
#  '거저': 5,
#  '거적': 4,
#  '거절': 15,
#  '거제': 6,
#  '거조': 1,
#  '거중': 5,
#  '거즈': 4,
#  '거즌': 1,
#  '거즘': 4,
#  '거지': 42,
#  '거짓': 11,
#  '거짓말': 33,
#  '거짓말쟁이': 1,
#  '거참': 1,
#  '거처': 1,
#  '거취': 2,
#  '거치': 78,
#  '거포': 1,
#  '거품': 79,
#  '거풍': 1,
#  '걱정': 84,
#  '건가': 176,
#  '건강': 20,
#  '건개': 1,
#  '건너': 3,
#  '건대': 3,
#  '건더기': 5,
#  '건데': 130,
#  '건데돈': 1,
#  '건데왜': 1,
#  '건등': 1,
#  '건만': 3,
#  '건물': 8,
#  '건뭐': 1,
#  '건반': 6,
#  '건선': 2,
#  '건성': 14,
#  '건성건성': 1,
#  '건쉽': 1,
#  '건시': 2,
#  '건아': 5,
#  '건안': 2,
#  '건어': 1,
#  '건어물': 2,
#  '건의': 2,
#  '건전': 3,
#  '건전지': 43,
#  '건조': 34,
#  '건조기': 40,
#  '건조대': 9,
#  '건조식품': 1,
#  '건주': 1,
#  '건줄': 5,
#  '건줄알': 1,
#  '건진': 1,
#  '건초': 1,
#  '건축': 1,
#  '건포도': 1,
#  '건후': 1,
#  '걷기': 3,
#  '걸곳': 2,
#  '걸꼬': 1,
#  '걸끈': 1,
#  '걸돈': 2,
#  '걸때': 1,
#  '걸레': 29,
#  '걸레질': 1,
#  '걸렛대': 1,
#  '걸렷': 9,
#  '걸렷구': 1,
#  '걸렷습니': 1,
#  '걸렷어': 3,
#  '걸롔': 1,
#  '걸론': 1,
#  '걸루': 3,
#  '걸류': 1,
#  '걸맇': 1,
#  '걸봉': 1,
#  '걸사': 3,
#  '걸살': 1,
#  '걸살걸': 1,
#  '걸속': 1,
#  '걸쇠': 1,
#  '걸알때': 1,
#  '걸왜': 3,
#  '걸왜삿': 1,
#  '걸음': 1,
#  '걸이': 96,
#  '걸인': 1,
#  '걸임': 1,
#  '걸죽함': 1,
#  '걸죽해': 1,
#  '걸줄': 1,
#  '걸쭉': 1,
#  '걸터': 1,
#  '걸팔': 1,
#  '걸핏하면': 1,
#  '검댕': 1,
#  '검사': 17,
#  '검색': 40,
#  '검수': 254,
#  '검은색': 69,
#  '검정': 62,
#  '검정색': 54,
#  '검증': 3,
#  '검지': 4,
#  '검품': 8,
#  '검핑': 1,
#  '겁질': 1,
#  '것때메': 1,
#  '것땜': 1,
#  '것반': 1,
#  '것임': 2,
#  '겄습': 1,
#  '겄어욛': 1,
#  '겄음': 2,
#  '겅질겅': 1,
#  '겉감': 2,
#  '겉도': 4,
#  '겉면': 4,
#  '겉모습': 2,
#  '겉모양': 4,
#  '겉바속쫄': 1,
#  '겉보기': 5,
#  '겉봉': 1,
#  '겉옷': 6,
#  '겉잎': 1,
#  '겉절이': 2,
#  '게년': 1,
#  '게다': 4,
#  '게다가': 29,
#  '게더': 2,
#  '게디': 1,
#  '게로': 1,
#  '게말': 1,
#  '게뭐': 7,
#  '게살': 10,
#  '게속': 2,
#  '게시': 3,
#  '게시리': 1,
#  '게시판': 10,
#  '게옷': 1,
#  '게이': 3,
#  '게인': 1,
#  '게임': 43,
#  '게임기': 1,
#  '게장': 19,
#  '게점': 1,
#  '게코': 1,
#  '게햇': 1,
#  '겐나': 1,
#  '겐조': 1,
#  '겔럭시탭': 1,
#  '겟어': 2,
#  '겟잇뷰티': 1,
#  '겨드랑이': 17,
#  '겨를': 3,
#  '겨우': 120,
#  '겨울': 55,
#  '겨울왕국': 4,
#  '겨울철': 5,
#  '겨자': 8,
#  '겨좀': 1,
#  '겨짐': 1,
#  '격감': 1,
#  '격격': 1,
#  '격었': 1,
#  '격자': 1,
#  '격차': 1,
#  '견갑골': 1,
#  '견고': 2,
#  '견과류': 8,
#  '견교하': 1,
#  '견본': 1,
#  '견용': 2,
#  '견인': 3,
#  '견적': 2,
#  '견주': 1,
#  '견해': 1,
#  '결과': 50,
#  '결과물': 2,
#  '결구': 1,
#  '결굴': 1,
#  '결귝': 1,
#  '결단': 1,
#  '결론': 27,
#  '결말': 1,
#  '결부': 18,
#  '결선': 1,
#  '결속': 3,
#  '결실': 1,
#  '결심': 2,
#  '결작': 1,
#  '결재': 16,
#  '결절': 1,
#  '결점': 3,
#  '결정': 38,
#  '결제': 67,
#  '결코': 4,
#  '결하': 1,
#  '결함': 3,
#  '결합': 8,
#  '결합도': 1,
#  '결합부': 4,
#  '결혼식': 4,
#  '결혼식장': 1,
#  '결후': 2,
#  '겸사겸사': 2,
#  '겸용': 2,
#  '겹겹': 2,
#  '겹롤': 1,
#  '겹말': 1,
#  '겹살': 1,
#  '겹쳐잇어몰랏': 1,
#  '겹치기': 1,
#  '경고': 1,
#  '경과': 5,
#  '경기도': 1,
#  '경도': 1,
#  '경량': 4,
#  '경로': 1,
#  '경리': 1,
#  '경미': 1,
#  '경보기': 1,
#  '경비실': 23,
#  '경사': 1,
#  '경상도': 3,
#  '경악': 3,
#  '경안': 1,
#  '경영': 1,
#  '경우': 102,
#  '경운': 1,
#  '경이': 3,
#  '경쟁': 1,
#  '경제': 2,
#  '경주빵': 1,
#  '경차': 3,
#  '경첩': 11,
#  '경추': 4,
#  '경포': 1,
#  '경향': 1,
#  '경험': 16,
#  '경화': 8,
#  '경황': 1,
#  '계고': 1,
#  '계곡': 1,
#  '계기': 9,
#  '계단': 8,
#  '계란': 55,
#  '계란말이': 1,
#  '계란후라이': 4,
#  '계량': 2,
#  '계량기': 1,
#  '계량컵': 2,
#  '계륵': 1,
#  '계박': 1,
#  '계방': 3,
#  '계산': 7,
#  '계산서': 1,
#  '계속': 595,
#  '계시': 5,
#  '계실': 1,
#  '계약': 1,
#  '계열': 5,
#  '계이': 1,
#  '계장': 2,
#  '계절': 7,
#  '계좌': 6,
#  '계착': 1,
#  '계피': 5,
#  '계획': 6,
#  '고가': 18,
#  '고갈': 2,
#  '고개': 11,
#  '고객': 206,
#  '고갱': 1,
#  '고고': 7,
#  '고교': 1,
#  '고구': 1,
#  '고구마': 153,
#  '고글': 3,
#  '고금': 1,
#  '고급': 30,
#  '고기': 185,
#  '고기랑': 1,
#  '고기만': 5,
#  '고난': 1,
#  '고니': 1,
#  '고다': 3,
#  '고담': 1,
#  '고대': 1,
#  '고대로': 7,
#  '고도': 9,
#  '고들빼기': 2,
#  '고등어': 7,
#  '고등학생': 1,
#  '고라니': 1,
#  '고래': 1,
#  '고량': 1,
#  '고려': 28,
#  '고로': 1,
#  '고루': 7,
#  '고르롭': 1,
#  '고름': 4,
#  '고리': 106,
#  '고마': 1,
#  '고마리': 1,
#  '고막': 1,
#  '고모': 1,
#  '고무': 186,
#  '고무밴드': 4,
#  '고무신': 3,
#  '고무장갑': 6,
#  '고무줄': 50,
#  '고문': 1,
#  '고물': 4,
#  '고물상': 1,
#  '고민': 115,
#  '고발': 11,
#  '고백': 1,
#  '고별': 4,
#  '고분': 1,
#  '고비': 1,
#  '고삐': 1,
#  '고사': 4,
#  '고사전': 1,
#  '고사하고': 1,
#  '고산': 16,
#  '고살': 2,
#  '고색': 2,
#  '고생': 128,
#  '고서': 5,
#  '고성': 1,
#  '고성능': 1,
#  '고속': 23,
#  '고속도로': 4,
#  '고스': 2,
#  '고스톱': 1,
#  '고시': 2,
#  '고시히카리': 3,
#  '고식': 1,
#  '고심': 1,
#  '고썻': 1,
#  '고아': 1,
#  '고안': 4,
#  '고압': 1,
#  '고약': 1,
#  '고양이': 35,
#  '고여': 6,
#  '고영': 1,
#  '고영상': 1,
#  '고오': 1,
#  '고온': 2,
#  '고요': 32,
#  '고용': 3,
#  '고위': 1,
#  '고의': 4,
#  '고이': 9,
#  '고인': 2,
#  '고인돌': 1,
#  '고자': 1,
#  '고작': 8,
#  '고장': 369,
#  '고재': 1,
#  '고저': 2,
#  '고전': 1,
#  '고정': 370,
#  '고정력': 8,
#  '고정문': 1,
#  '고정용': 4,
#  '고정은': 3,
#  '고지': 13,
#  '고지도': 2,
#  '고진': 1,
#  '고질': 2,
#  '고집': 2,
#  '고차': 1,
#  '고참': 1,
#  '고체': 1,
#  '고추': 31,
#  '고추가': 9,
#  '고추장': 9,
#  '고춧가루': 10,
#  '고치': 1,
#  '고통': 7,
#  '고하': 8,
#  '고함': 9,
#  '고합': 2,
#  '고해': 65,
#  '고행': 1,
#  '고향': 1,
#  '고형': 1,
#  '고화질': 1,
#  '고환': 2,
#  '고후': 2,
#  '고흐': 2,
#  '고희': 1,
#  '곡객': 1,
#  '곡면': 6,
#  '곡물': 6,
#  '곡선': 7,
#  '곤데': 1,
#  '곤란': 16,
#  '곤약': 2,
#  '곤쟁이': 2,
#  '곤죽': 3,
#  '곤지': 3,
#  '곤충': 2,
#  '곧바로': 1,
#  '곧장': 1,
#  '골도': 1,
#  '골드': 49,
#  '골드코스트': 2,
#  '골림': 1,
#  '골목': 1,
#  '골반': 19,
#  '골뱅이': 4,
#  '골슬머리': 1,
#  '골지': 3,
#  '골치': 1,
#  '골트': 1,
#  '골프': 6,
#  '곰돌이': 3,
#  '곰보': 2,
#  '곰삭': 1,
#  '곰손': 1,
#  '곰팡이': 124,
#  '곱돌': 1,
#  '곱슬': 2,
#  '곱창': 26,
#  '곳곳': 18,
#  '곳곳이': 1,
#  '곳도': 28,
#  '곳알': 1,
#  '곳애': 1,
#  '곳임': 2,
#  '공간': 53,
#  '공간활용': 2,
#  '공갈': 6,
#  '공감': 2,
#  '공개처형': 1,
#  '공격': 2,
#  '공공장소': 2,
#  '공교': 1,
#  '공구': 18,
#  '공급': 3,
#  '공기': 46,
#  '공기청정기': 2,
#  '공도': 1,
#  '공동': 3,
#  '공란': 1,
#  '공룡': 5,
#  '공명': 1,
#  '공무': 1,
#  '공병': 9,
#  '공복': 2,
#  '공부': 9,
#  '공비': 1,
#  '공사': 2,
#  '공산품': 3,
#  '공식': 9,
#  '공업': 3,
#  '공연장': 1,
#  '공용': 4,
#  '공원': 1,
#  '공유': 3,
#  '공유기': 5,
#  '공이': 11,
#  '공익': 1,
#  '공임': 2,
#  '공장': 17,
#  '공적': 3,
#  '공정': 3,
#  '공제': 1,
#  '공주': 2,
#  '공중': 5,
#  '공중화장실': 1,
#  '공지': 40,
#  '공진': 1,
#  '공짜': 11,
#  '공차': 4,
#  '공책': 3,
#  '공카': 1,
#  '공판': 6,
#  '공팡': 1,
#  '공한': 1,
#  '공항': 32,
#  '공해': 2,
#  '공홈': 4,
#  '공휴일': 4,
#  '곶감': 5,
#  '과감': 2,
#  '과거': 2,
#  '과다르': 5,
#  '과당': 1,
#  '과대': 41,
#  '과도': 1,
#  '과메기': 1,
#  '과세': 1,
#  '과숙': 1,
#  '과숙됐': 1,
#  ...}

# %%
wc = word_count_dict

wordCloud = WordCloud(
    font_path = "malgun",        # 폰트 지정
    background_color = 'white',  # 배경색 지정
    stopwords = stopwords,       # 불용어 지정
    mask = mask,                 # 워드 클라우드 mask 지정
    width = 1000,                # 워드 클라우드의 너비 지정
    height = 1000,               # 워드클라우드의 높이 지정
    # max_font_size=100,         # 가장 빈도수가 높은 단어의 폰트 사이즈 지정
).generate_from_frequencies(wc)  # 워드 클라우드 빈도수 지정

plt.figure()  
plt.imshow(wordCloud)
plt.axis('off')
plt.show();

# %%
wordCloud.words_
# Out:
# {'배송': 1.0,
#  '그냥': 0.8804247460757156,
#  '별로': 0.6632040627885504,
#  '제품': 0.5955678670360111,
#  '사용': 0.5685595567867036,
#  '구매': 0.5551708217913204,
#  '주문': 0.44967682363804246,
#  '반품': 0.44113573407202217,
#  '생각': 0.37442289935364725,
#  '냄새': 0.3670360110803324,
#  '상품': 0.36426592797783935,
#  '가격': 0.3407202216066482,
#  '진짜': 0.3344875346260388,
#  '부분': 0.3317174515235457,
#  '하나': 0.31786703601108035,
#  '포장': 0.3125577100646353,
#  '사이즈': 0.30863342566943675,
#  '정말': 0.2737765466297322,
#  '교환': 0.2566943674976916,
#  '정도': 0.25,
#  '다시': 0.22276084949215144,
#  '실망': 0.22045244690674054,
#  '완전': 0.22022160664819945,
#  '한번': 0.2146814404432133,
#  '불량': 0.20313942751615882,
#  '처음': 0.19990766389658357,
#  '최악': 0.19852262234533702,
#  '사진': 0.1904432132963989,
#  '박스': 0.1819021237303786,
#  '상태': 0.1814404432132964,
#  '보고': 0.17890120036934443,
#  '물건': 0.16897506925207756,
#  '다른': 0.1682825484764543,
#  '확인': 0.16528162511542013,
#  '택배': 0.1530470914127424,
#  '느낌': 0.15143120960295475,
#  '판매': 0.14312096029547552,
#  '구입': 0.14104339796860574,
#  '효과': 0.1394275161588181,
#  '바로': 0.13781163434903046,
#  '계속': 0.13734995383194828,
#  '리뷰': 0.13550323176361959,
#  '시간': 0.13504155124653738,
#  '이건': 0.12765466297322253,
#  '환불': 0.12696214219759927,
#  '제대로': 0.12142197599261312,
#  '전혀': 0.12096029547553093,
#  '연락': 0.12049861495844875,
#  '기분': 0.11911357340720222,
#  '마감': 0.11703601108033242,
#  '절대': 0.11703601108033242,
#  '여기': 0.11195752539242844,
#  '조금': 0.11080332409972299,
#  '이번': 0.10133887349953832,
#  '크기': 0.09995383194829179,
#  '잘못': 0.09626038781163435,
#  '처리': 0.09602954755309326,
#  '사지': 0.09556786703601108,
#  '조립': 0.0951061865189289,
#  '후기': 0.09464450600184672,
#  '색상': 0.09210526315789473,
#  '때문': 0.0904893813481071,
#  '전화': 0.08933518005540166,
#  '구멍': 0.08887349953831948,
#  '문의': 0.08818097876269622,
#  '설치': 0.08748845798707294,
#  '자꾸': 0.08725761772853186,
#  '문제': 0.08702677746999077,
#  '아주': 0.0865650969529086,
#  '뚜껑': 0.0861034164358264,
#  '고정': 0.08541089566020314,
#  '고장': 0.08518005540166206,
#  '충전': 0.08518005540166206,
#  '일주일': 0.0840258541089566,
#  '아이': 0.08333333333333333,
#  '하루': 0.08310249307479224,
#  '다음': 0.08287165281625115,
#  '소리': 0.08148661126500462,
#  '엉망': 0.07987072945521699,
#  '쓰레기': 0.07779316712834719,
#  '원래': 0.07779316712834719,
#  '사람': 0.07686980609418283,
#  '추천': 0.07686980609418283,
#  '재질': 0.07640812557710065,
#  '일단': 0.07571560480147738,
#  '세탁': 0.07502308402585411,
#  '먼지': 0.07479224376731301,
#  '설명': 0.07479224376731301,
#  '달라': 0.07363804247460758,
#  '신경': 0.07340720221606649,
#  '참고': 0.07340720221606649,
#  '착용': 0.0729455216989843,
#  '대비': 0.07225300092336104,
#  '거의': 0.07040627885503231,
#  '케이스': 0.06971375807940905,
#  '이상': 0.06948291782086796,
#  '선물': 0.06809787626962142,
#  '배송비': 0.06786703601108034,
#  '만원': 0.06763619575253925,
#  '후회': 0.06578947368421052,
#  '머리': 0.06486611265004617,
#  '역시': 0.06278855032317636,
#  '디자인': 0.06209602954755309,
#  '작고': 0.061865189289012,
#  '마리': 0.06140350877192982,
#  '물이': 0.060941828254847646,
#  '아기': 0.060941828254847646,
#  '접착': 0.060941828254847646,
#  '유통': 0.06071098799630656,
#  '매우': 0.060480147737765465,
#  '광고': 0.05955678670360111,
#  '길이': 0.05909510618651893,
#  '검수': 0.05863342566943675,
#  '가요': 0.05840258541089566,
#  '연결': 0.05840258541089566,
#  '무슨': 0.0574792243767313,
#  '품질': 0.0574792243767313,
#  '금방': 0.057248384118190214,
#  '몇번': 0.057248384118190214,
#  '해도': 0.056555863342566945,
#  '기한': 0.05632502308402586,
#  '사서': 0.05632502308402586,
#  '지금': 0.05632502308402586,
#  '나사': 0.055863342566943676,
#  '그대로': 0.05563250230840259,
#  '비닐': 0.05563250230840259,
#  '비지': 0.05517082179132041,
#  '추가': 0.05355493998153278,
#  '자체': 0.05240073868882733,
#  '피부': 0.05240073868882733,
#  '차이': 0.05216989843028624,
#  '바람': 0.05193905817174515,
#  '다리': 0.05170821791320406,
#  '바닥': 0.05170821791320406,
#  '뭔가': 0.050784856879039705,
#  '플라스틱': 0.050784856879039705,
#  '답변': 0.05055401662049862,
#  '아예': 0.050092336103416436,
#  '한쪽': 0.049630655586334255,
#  '도착': 0.04939981532779317,
#  '쓰기': 0.04916897506925208,
#  '요청': 0.048938134810710986,
#  '확정': 0.048938134810710986,
#  '정품': 0.04847645429362881,
#  '자마자': 0.04778393351800554,
#  '취소': 0.04778393351800554,
#  '고객': 0.04755309325946445,
#  '커버': 0.04686057248384118,
#  '구성': 0.046398891966759004,
#  '누가': 0.046398891966759004,
#  '오늘': 0.046398891966759004,
#  '파손': 0.046168051708217916,
#  '테이프': 0.04547553093259465,
#  '업체': 0.04524469067405355,
#  '이유': 0.04524469067405355,
#  '바지': 0.04478301015697138,
#  '화면': 0.044552169898430284,
#  '의자': 0.0443213296398892,
#  '손잡이': 0.04409048938134811,
#  '마음': 0.043859649122807015,
#  '중간': 0.043859649122807015,
#  '필름': 0.043167128347183746,
#  '고무': 0.04293628808864266,
#  '고기': 0.04270544783010157,
#  '자국': 0.04270544783010157,
#  '별루': 0.04224376731301939,
#  '신청': 0.0420129270544783,
#  '얼굴': 0.0420129270544783,
#  '대충': 0.04178208679593721,
#  '안나': 0.04155124653739612,
#  '거리': 0.041089566020313946,
#  '건가': 0.040627885503231764,
#  '스티커': 0.04016620498614958,
#  '의사': 0.04016620498614958,
#  '서비스': 0.039935364727608495,
#  '가지': 0.03970452446906741,
#  '기사': 0.03970452446906741,
#  '살짝': 0.03970452446906741,
#  '모기': 0.038781163434903045,
#  '심해': 0.03785780240073869,
#  '장난': 0.03785780240073869,
#  '지퍼': 0.03785780240073869,
#  '가루': 0.037396121883656507,
#  '작동': 0.037396121883656507,
#  '직접': 0.036703601108033244,
#  '기스': 0.03647276084949215,
#  '싸구려': 0.03624192059095106,
#  '고구마': 0.035318559556786706,
#  '먹기': 0.03508771929824561,
#  '마스크': 0.034856879039704525,
#  '모양': 0.034856879039704525,
#  '일반': 0.03462603878116344,
#  '한지': 0.03462603878116344,
#  '마트': 0.03439519852262234,
#  '커서': 0.03439519852262234,
#  '가방': 0.034164358264081256,
#  '나무': 0.034164358264081256,
#  '전체': 0.034164358264081256,
#  '짜증': 0.034164358264081256,
#  '크게': 0.034164358264081256}

# %% [markdown]
# ## (2) Score_2_Review

# %%
text = ''
filePath = './data/Score_2_Review.txt'
with open(filePath, "r", encoding="utf-8") as f:
    lines = f.readlines()
    for line in lines:
        text += line

# %%
vect = CountVectorizer(tokenizer = lambda x : text_cleaning(x))
bow_vect = vect.fit_transform([text])
word_list = vect.get_feature_names_out()
count_list = bow_vect.toarray().sum(axis = 0)

word_count_dict = dict(zip(word_list, count_list))

# %%
wc = word_count_dict

wordCloud = WordCloud(
    font_path = "malgun",        # 폰트 지정
    background_color = 'white',  # 배경색 지정
    stopwords = stopwords,       # 불용어 지정
    mask = mask,                 # 워드 클라우드 mask 지정
    width = 1000,                # 워드 클라우드의 너비 지정
    height = 1000,               # 워드클라우드의 높이 지정
    # max_font_size=100,         # 가장 빈도수가 높은 단어의 폰트 사이즈 지정
).generate_from_frequencies(wc)  # 워드 클라우드 빈도수 지정

plt.figure()  
plt.imshow(wordCloud)
plt.axis('off')
plt.show();

# %% [markdown]
# ## (3) Score_4_Review

# %%
text = ''
filePath = './data/Score_4_Review.txt'
with open(filePath, "r", encoding="utf-8") as f:
    lines = f.readlines()
    for line in lines:
        text += line

# %%
vect = CountVectorizer(tokenizer = lambda x : text_cleaning(x))
bow_vect = vect.fit_transform([text])
word_list = vect.get_feature_names_out()
count_list = bow_vect.toarray().sum(axis = 0)

word_count_dict = dict(zip(word_list, count_list))

# %%
wc = word_count_dict

wordCloud = WordCloud(
    font_path = "malgun",        # 폰트 지정
    background_color = 'white',  # 배경색 지정
    stopwords = stopwords,       # 불용어 지정
    mask = mask,                 # 워드 클라우드 mask 지정
    width = 1000,                # 워드 클라우드의 너비 지정
    height = 1000,               # 워드클라우드의 높이 지정
    # max_font_size=100,         # 가장 빈도수가 높은 단어의 폰트 사이즈 지정
).generate_from_frequencies(wc)  # 워드 클라우드 빈도수 지정

plt.figure()  
plt.imshow(wordCloud)
plt.axis('off')
plt.show();

# %% [markdown]
# ## (4) Score_5_Review

# %%
text = ''
filePath = './data/Score_5_Review.txt'
with open(filePath, "r", encoding="utf-8") as f:
    lines = f.readlines()
    for line in lines:
        text += line

# %%
vect = CountVectorizer(tokenizer = lambda x : text_cleaning(x))
bow_vect = vect.fit_transform([text])
word_list = vect.get_feature_names_out()
count_list = bow_vect.toarray().sum(axis = 0)

word_count_dict = dict(zip(word_list, count_list))

# %%
wc = word_count_dict

wordCloud = WordCloud(
    font_path = "malgun",        # 폰트 지정
    background_color = 'white',  # 배경색 지정
    stopwords = stopwords,       # 불용어 지정
    mask = mask,                 # 워드 클라우드 mask 지정
    width = 1000,                # 워드 클라우드의 너비 지정
    height = 1000,               # 워드클라우드의 높이 지정
    # max_font_size=100,         # 가장 빈도수가 높은 단어의 폰트 사이즈 지정
).generate_from_frequencies(wc)  # 워드 클라우드 빈도수 지정

plt.figure()  
plt.imshow(wordCloud)
plt.axis('off')
plt.show();
